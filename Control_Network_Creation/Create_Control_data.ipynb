# %%
import pandas as pd

df_nodes = pd.read_csv("network/Successful Network/Original Network/nodes_original.csv", sep="\t")
df_nodes
# Out:
#         Id                       name  popularity  followers  \
# 0        1                   2 Chainz          83    3141364
# 1        2                      Drake         100   23732186
# 2        3                      Quavo          84    1819632
# 3        4              Ty Dolla $ign          87    1939644
# 4        5                 Trey Songz          75    3256433
# ...    ...                        ...         ...        ...
# 2147  2148               Matthew Koma          61      68641
# 2148  2149  Rome of Sublime with Rome          39         93
# 2149  2150                  Matisyahu          60     437153
# 2150  2151    The Unlikely Candidates          53      29455
# 2151  2152                       Maná          72    3157313
#
#                                                  genres  \
# 0     hip hop, pop, pop rap, rap, southern hip hop, ...
# 1     canadian hip hop, canadian pop, hip hop, pop r...
# 2                                                   NaN
# ...

# %%
df_edges = pd.read_csv("network/Successful Network/Original Network/edgelist_original.csv", sep="\t")
df_edges
# Out:
#      Source  Target        Type     Id  Weight                  label1  \
# 0         1      33  Undirected  23121       2  17lzZA2AlOHwCwFALHttmp
# 1         1     675  Undirected  21681       2  17lzZA2AlOHwCwFALHttmp
# 2         1    1998  Undirected  21680       2  17lzZA2AlOHwCwFALHttmp
# 3         1     223  Undirected  21337       2  17lzZA2AlOHwCwFALHttmp
# 4         1     869  Undirected  19593       2  17lzZA2AlOHwCwFALHttmp
# ..      ...     ...         ...    ...     ...                     ...
# 917    1368    1371  Undirected  15186       2  23fqKkggKUBHNkbKtXEls4
# 918    1397    1796  Undirected  19798       2  3t5xRXzsuZmMDkQzgOX35S
# 919    1397    1794  Undirected  19794       2  3t5xRXzsuZmMDkQzgOX35S
# 920    1431    1451  Undirected  15818       2  2kCcBybjl3SAtIcwdWpUe3
# 921    1940    2144  Undirected  21327       2  06HL4z0CvFAxyc27GXpf02
#
#                      label2         name1         name2  id_track  \
# ...

# %%
df_edges["Weight"].max()
# Out:
# 24

# %%
import matplotlib.pyplot as plt

weight_counts = df_edges['Weight'].value_counts()

plt.figure(figsize=(10, 6))
weight_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Weight')
plt.ylabel('Count')
plt.title('Occurrence of Unique Weights')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
df_edges[(df_edges["name1"] == df_edges["name2"])]
# Out:
# Empty DataFrame
# Columns: [Source, Target, Type, Id, Weight, label1, label2, name1, name2, id_track, label_track, title, explicit, popularity, release_date, release_date_precision]
# Index: []

# %%
unique_weights = df_edges['Weight'].unique()
print(unique_weights)
# Out:
# [ 2  4  6  8 10 24 12]

# %% [markdown]
# alle nur gerade, => default weight = 2 für 2 verschiedene artists
#
# jede Erhöhung ist ebenfalls gerade. => Erhöhung immer um 2

# %% [markdown]
# also alle artists extrahieren anzahl der Songs zwischen artists errechnen und überprüfen udn dann netzwerk erstellen
# Frage was ist mit selfloopern?
#
# auch in online repräsentation scheinen selfedges nicht aufzutauchen.
#
# https://homepages.dcc.ufmg.br/~mariana.santos/comusic/

# %%
liste = []
for _, row in df_edges.iterrows():
    if row["Weight"] == 2:
        liste.append(row)
    elif row["Weight"] > 2:
        for i in range(int(row["Weight"] / 2)):
            liste.append(row)
            
df_res = pd.DataFrame(liste, columns=df_edges.columns)
df_res
# Out:
#      Source  Target        Type     Id  Weight                  label1  \
# 0         1      33  Undirected  23121       2  17lzZA2AlOHwCwFALHttmp
# 1         1     675  Undirected  21681       2  17lzZA2AlOHwCwFALHttmp
# 2         1    1998  Undirected  21680       2  17lzZA2AlOHwCwFALHttmp
# 3         1     223  Undirected  21337       2  17lzZA2AlOHwCwFALHttmp
# 4         1     869  Undirected  19593       2  17lzZA2AlOHwCwFALHttmp
# ..      ...     ...         ...    ...     ...                     ...
# 917    1368    1371  Undirected  15186       2  23fqKkggKUBHNkbKtXEls4
# 918    1397    1796  Undirected  19798       2  3t5xRXzsuZmMDkQzgOX35S
# 919    1397    1794  Undirected  19794       2  3t5xRXzsuZmMDkQzgOX35S
# 920    1431    1451  Undirected  15818       2  2kCcBybjl3SAtIcwdWpUe3
# 921    1940    2144  Undirected  21327       2  06HL4z0CvFAxyc27GXpf02
#
#                      label2         name1         name2  id_track  \
# ...

# %%
df_res.to_csv('Kontrolldaten/Songs.csv', index=False)

# %%
# Assuming df is your DataFrame and you want to drop columns at index 0 and 2
columns_to_drop = [6, 7,8,9,10,11,12,13,14]  # List of column indices to drop
df_nodes.drop(df_nodes.columns[columns_to_drop], axis=1, inplace=True)

# %%
df_nodes
# Out:
#         Id                       name  popularity  followers  \
# 0        1                   2 Chainz          83    3141364
# 1        2                      Drake         100   23732186
# 2        3                      Quavo          84    1819632
# 3        4              Ty Dolla $ign          87    1939644
# 4        5                 Trey Songz          75    3256433
# ...    ...                        ...         ...        ...
# 2147  2148               Matthew Koma          61      68641
# 2148  2149  Rome of Sublime with Rome          39         93
# 2149  2150                  Matisyahu          60     437153
# 2150  2151    The Unlikely Candidates          53      29455
# 2151  2152                       Maná          72    3157313
#
#                                                  genres  \
# 0     hip hop, pop, pop rap, rap, southern hip hop, ...
# 1     canadian hip hop, canadian pop, hip hop, pop r...
# 2                                                   NaN
# ...

# %%
df_nodes.to_csv('Kontrolldaten/Artists.csv', index=False)
