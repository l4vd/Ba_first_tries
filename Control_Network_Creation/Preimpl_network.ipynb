# %%
import pandas as pd

df_nodes = pd.read_csv("network/Successful Network/Original Network/nodes_original.csv", sep="\t")
df_nodes
# Out:
#         Id                       name  popularity  followers  \
# 0        1                   2 Chainz          83    3141364
# 1        2                      Drake         100   23732186
# 2        3                      Quavo          84    1819632
# 3        4              Ty Dolla $ign          87    1939644
# 4        5                 Trey Songz          75    3256433
# ...    ...                        ...         ...        ...
# 2147  2148               Matthew Koma          61      68641
# 2148  2149  Rome of Sublime with Rome          39         93
# 2149  2150                  Matisyahu          60     437153
# 2150  2151    The Unlikely Candidates          53      29455
# 2151  2152                       Maná          72    3157313
#
#                                                  genres  \
# 0     hip hop, pop, pop rap, rap, southern hip hop, ...
# 1     canadian hip hop, canadian pop, hip hop, pop r...
# 2                                                   NaN
# ...

# %%
df_nodes.iloc[:, 6:-1].max()
# Out:
# degree                          35.000000
# weighted degree                108.000000
# Eccentricity                     8.000000
# closnesscentrality               1.000000
# harmonicclosnesscentrality       1.000000
# betweenesscentrality             0.001174
# modularity_class              1910.000000
# clustering                       1.000000
# eigencentrality                  1.000000
# dtype: float64

# %%
# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=len(df_nodes.iloc[:, 6:-1].columns), figsize=(15, 5))

# Plot boxplots for each column
for i, column in enumerate(df_nodes.iloc[:, 6:-1].columns):
    df_nodes[column].plot(kind='box', ax=axes[i])
    axes[i].set_title(column)

plt.tight_layout()
plt.show()

# %%
df_edges = pd.read_csv("network/Successful Network/Original Network/edgelist_original.csv", sep="\t")
df_edges
# Out:
#      Source  Target        Type     Id  Weight                  label1  \
# 0         1      33  Undirected  23121       2  17lzZA2AlOHwCwFALHttmp
# 1         1     675  Undirected  21681       2  17lzZA2AlOHwCwFALHttmp
# 2         1    1998  Undirected  21680       2  17lzZA2AlOHwCwFALHttmp
# 3         1     223  Undirected  21337       2  17lzZA2AlOHwCwFALHttmp
# 4         1     869  Undirected  19593       2  17lzZA2AlOHwCwFALHttmp
# ..      ...     ...         ...    ...     ...                     ...
# 917    1368    1371  Undirected  15186       2  23fqKkggKUBHNkbKtXEls4
# 918    1397    1796  Undirected  19798       2  3t5xRXzsuZmMDkQzgOX35S
# 919    1397    1794  Undirected  19794       2  3t5xRXzsuZmMDkQzgOX35S
# 920    1431    1451  Undirected  15818       2  2kCcBybjl3SAtIcwdWpUe3
# 921    1940    2144  Undirected  21327       2  06HL4z0CvFAxyc27GXpf02
#
#                      label2         name1         name2  id_track  \
# ...

# %%
df_songs = pd.read_csv("billboard/Billboard Charts/hot100.csv", sep="\t")
df_songs
# Out:
#               date                       title  \
# 0       2018-08-25              In My Feelings
# 1       2018-08-25              Girls Like You
# 2       2018-08-25                   I Like It
# 3       2018-08-25                        FEFE
# 4       2018-08-25                  Better Now
# ...            ...                         ...
# 313395  1958-08-11            Down In Virginia
# 313396  1958-08-11             Sunday Barbecue
# 313397  1958-08-11             Gotta Have Rain
# 313398  1958-08-11        Nothing In The World
# 313399  1958-08-11  Baubles, Bangles And Beads
#
#                                              artist  peakPos  lastPos  weeks  \
# 0                                             Drake        1        1      7
# 1                        Maroon 5 Featuring Cardi B        2        2     12
# 2                     Cardi B, Bad Bunny & J Balvin        1        3     19
# 3       6ix9ine Featuring Nicki Minaj & Murda Beatz        3        5      4
# ...

# %%
import networkx as nx


# Load the network from the GEXF file
G = nx.read_gexf('network/Successful Network/Original Network/original_network.gexf')

# Now you can use the NetworkX functions to analyze or visualize the network
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# Cell In[15], line 5
#       1 import networkx as nx
#       4 # Load the network from the GEXF file
# ----> 5 G = nx.read_gexf('network/Successful Network/Original Network/original_network.gexf')
#
# File <class 'networkx.utils.decorators.argmap'> compilation 5:5, in argmap_read_gexf_1(path, node_type, relabel, version)
#       3 import gzip
#       4 import inspect
# ----> 5 import itertools
#       6 import re
#       7 from collections import defaultdict
#
# File ~\anaconda3\envs\Ba_first_tries\lib\site-packages\networkx\readwrite\gexf.py:175, in read_gexf(path, node_type, relabel, version)
#     173     G = relabel_gexf_graph(reader(path))
#     174 else:
# --> 175     G = reader(path)
#     176 return G
#
# ...

# %%
import networkx as nx
import pandas as pd


# Create a graph object
G = nx.Graph()

# Add nodes with attributes to the graph
for _, row in df_nodes.iterrows():
    node_attrs = {attr: row[attr] for attr in df_nodes.columns if attr != 'name'}
    G.add_node(row['name'], **node_attrs)

# Add edges with attributes to the graph
for _, row in df_edges.iterrows():
    edge_attrs = {attr: row[attr] for attr in df_edges.columns if attr not in ['name1', 'name2']}
    G.add_edge(row['name1'], row['name2'], **edge_attrs)

# Alternatively, you can directly read the entire network from the GEXF file
# G = nx.read_gexf('path_to_your_file/original_network.gexf')

# %%
import matplotlib.pyplot as plt

# Draw the graph
nx.draw(G, with_labels=False, node_color='skyblue', node_size=1, edge_color='black', linewidths=1, font_size=15)

# Display the plot
plt.savefig("network.png")
plt.show()
